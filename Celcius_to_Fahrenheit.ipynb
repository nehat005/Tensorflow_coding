# %% [markdown]
# <a href="https://colab.research.google.com/github/nehat005/Tensorflow_coding/blob/main/Celcius_to_Fahrenheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Statement:
#
# **Celsius to Fahrenheit**:
#
# F = 1.8 * C + 32

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# # TRAINING DATA:

# %%
celcius_temp = np.array([-40, -10, 0, 8, 15, 22, 38, 40], dtype = float)
fahrenheit_temp = np.array([-40, 14, 32, 46.0, 59, 72, 100.0, 104], dtype = float)

# %% [markdown]
# # Create and Train a Simple Neural Net

# %%
l0 = tf.keras.layers.Dense(1, input_shape = (1,))

model = tf.keras.Sequential([l0])

# %% [markdown]
# Compile the Model with Loss and Optimizer

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(0.1), loss = 'mean_squared_error')

# %% [markdown]
# Train the model

# %%
history = model.fit(celcius_temp, fahrenheit_temp, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 284ms/step - loss: 1371.2975
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1257.0203
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1157.4019
# Epoch 4/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1072.5748
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1002.4762
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 946.7806
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 904.8343
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 875.5887
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 857.5587
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 848.8267
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 847.1204
# Epoch 12/500
# ...

# %% [markdown]
# #Training Statistics

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.xlabel('Epoch Number')
plt.ylabel('Error')
plt.title('Training Error')
plt.grid()
plt.plot(history.history['loss'])

# %%
print(model.weights)
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[1.8350092]], dtype=float32)>, <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32, numpy=array([29.234953], dtype=float32)>]

# %%
print(model.predict([100]))
# Out:
# [[212.73587]]

# %% [markdown]
# According to the formula: y = 1.8 x + 32
#
# If x = 100, then y = 1.8 * 100 + 32 = 180+32 = 212
